# %% [markdown]
# # Kubeflow - Pipeline steps development

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.7/site-packages (1.3.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from xgboost) (1.6.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from xgboost) (1.19.5)

# %%
'''
Wrapper around the preprocessing function.
This code perform:

- Data loading from local files (debug) or GCP bigquery
- Save data as DMatrix
'''
import argparse
import logging
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from google.cloud import storage

# logger configuration
logging.basicConfig(format='%(asctime)s | %(levelname)s: %(message)s', level=logging.NOTSET)

def _get_blob_bucket(bucket_name, path, destination):
    """Downloads a blob from the bucket."""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)

    blob = bucket.blob(path)
    blob.download_to_filename(destination)
    
    logging.info('Exoplanets Pipeline: Blob {} downloaded to {}'.format(path, destination))
    return destination

def _upload_blob_bucket(bucket_name, source_file_name, destination):
    """Uploads a file to the bucket."""

    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    
    blob = bucket.blob(destination)
    blob.upload_from_filename(source_file_name)
    
    logging.info('Exoplanets Pipeline: Blob {} uploaded to {}'.format(source_file_name, 
                                                                                   destination))
    
def _local_loader(path, label_column_index, skiprows=1, delimiter=','):
    '''
    Light-weight txt files data loader that uses numpy as backend
    '''
    dataset = {}
    raw = np.loadtxt(path, skiprows=1, delimiter=',')
    x = raw[:, label_column_index+1:]
    y = raw[:, label_column_index, np.newaxis] - 1. # -1 to report label in the range 0-1
    return x, y


def preprocess_data(bucket, local=True):
    LABEL_COLUMN_INDEX = 0
    
    logging.info('Exoplanets Pipeline - Preprocess: Paths creation with {0} bucket'.format(bucket))
    # define input bucket-path of the data
    train_dataset_path = _get_blob_bucket(bucket, "data/exoTrain.csv", "exoTrain.csv")
    test_dataset_path = _get_blob_bucket(bucket, "data/exoTest.csv", "exoTest.csv")
                              
    logging.info('Exoplanets Pipeline - Preprocess: Data import')
    x, y = _local_loader(path=train_dataset_path, label_column_index=LABEL_COLUMN_INDEX)
    # create an additonal evaluation split
    x_train, x_eval, y_train, y_eval = train_test_split(x, y,
                                                        stratify=y,
                                                        test_size=0.25)
    x_test, y_test = _local_loader(path=test_dataset_path, label_column_index=LABEL_COLUMN_INDEX)
    # save results as DMatrix for better performances on xgboost
    dtrain = xgb.DMatrix(x_train, label=y_train)
    deval = xgb.DMatrix(x_eval, label=y_eval)
    dtest = xgb.DMatrix(x_test, label=y_test)
    
    logging.info('Exoplanets Pipeline - Preprocess: Store data set as DMatrix')
    xgb.DMatrix.save_binary(dtrain, "train_dmatrix.data")
    xgb.DMatrix.save_binary(deval, "eval_dmatrix.data")
    xgb.DMatrix.save_binary(dtest, "test_dmatrix.data")
    
    # upload data on the storage
    _upload_blob_bucket(bucket, "train_dmatrix.data", "preprocess/train_dmatrix.data")
    _upload_blob_bucket(bucket, "eval_dmatrix.data", "preprocess/eval_dmatrix.data")
    _upload_blob_bucket(bucket, "test_dmatrix.data", "preprocess/test_dmatrix.data")
    
    logging.info('Exoplanets Pipeline - Preprocess: Completed')

# %%
bucket = "exoplanets_kubeflow"

# %%
logging.info('Exoplanets Pipeline - Preprocess: Running...')
preprocess_data(bucket)
# Out:
# 2021-02-22 16:42:30,866 | INFO: Exoplanets Pipeline - Preprocess: Running...
# 2021-02-22 16:42:30,868 | INFO: Exoplanets Pipeline - Preprocess: Paths creation with exoplanets_kubeflow bucket
# 2021-02-22 16:42:30,869 | DEBUG: Checking None for explicit credentials as part of auth process...
# 2021-02-22 16
| DEBUG: http://metadata.google.internal:80 "GET /computeMetadata/v1/instance/service-accounts/806181930442-compute@developer.gserviceaccount.com/token?scopes=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_only%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_write HTTP/1.1" 200 260
# 2021-02-22 16:42:47,427 | DEBUG: Starting new HTTPS connection (1): storage.googleapis.com:443
# 2021-02-22 16:42:47,538 | DEBUG: https://storage.googleapis.com:443 "POST /upload/storage/v1/b/exoplanets_kubeflow/o?uploadType=resumable HTTP/1.1" 200 0
# 2021-02-22 16:42:48,887 | DEBUG: https://storage.googleapis.com:443 "PUT /upload/storage/v1/b/exoplanets_kubeflow/o?uploadType=resumable&upload_id=ABg5-UyAN7YXhpkfPsYBeMpXVb8o_VJJS3yfBQ8EKT4cTGKrgyhppqiDn-hakVZAmFIIhKM-sc_DhcPrMARx32FVDwHvjBqb8Q HTTP/1.1" 200 857
# 2021-02-22 16:42:48,889 | INFO: Exoplanets Pipeline: Blob train_dmatrix.data uploaded to preprocess/train_dmatrix.data
# 2021-02-22 16:42:48,890 | DEBUG: Checking None for explicit credentials as part of auth process...
# 2021-02-22 16:42:48,891 | DEBUG: Checking Cloud SDK credentials as part of auth process...
# 2021-02-22 16:42:48,892 | DEBUG: Cloud SDK credentials not found on disk; not using them
# 2021-02-22 16:42:48,893 | DEBUG: Checking for App Engine runtime as part of auth process...
# 2021-02-22 16:42:48,893 | DEBUG: No App Engine library was found so cannot authentication via App Engine Identity Credentials.
# 2021-02-22 16:42:48,895 | DEBUG: Making request: GET http://169.254.169.254
# 2021-02-22 16:42:48,899 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/project/project-id
# 2021-02-22 16:42:48,904 | DEBUG: Checking None for explicit credentials as part of auth process...
# 2021-02-22 16:42:48,905 | DEBUG: Checking Cloud SDK credentials as part of auth process...
# 2021-02-22 16:42:48,905 | DEBUG: Cloud SDK credentials not found on disk; not using them
# 2021-02-22 16:42:48,907 | DEBUG: Checking for App Engine runtime as part of auth process...
# 2021-02-22 16:42:48,908 | DEBUG: No App Engine library was found so cannot authentication via App Engine Identity Credentials.
# 2021-02-22 16:42:48,909 | DEBUG: Making request: GET http://169.254.169.254
# 2021-02-22 16:42:48,912 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/project/project-id
# 2021-02-22 16:42:48,916 | DEBUG: Converted retries value: 3 -> Retry(total=3, connect=None, read=None, redirect=None, status=None)
# 2021-02-22 16:42:48,917 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true
# 2021-02-22 16:42:48,919 | DEBUG: Starting new HTTP connection (1): metadata.google.internal:80
# 2021-02-22 16:42:48,923 | DEBUG: http://metadata.google.internal:80 "GET /computeMetadata/v1/instance/service-accounts/default/?recursive=true HTTP/1.1" 200 193
# 2021-02-22 16:42:48,925 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/806181930442-compute@developer.gserviceaccount.com/token?scopes=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_only%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_write
# 2021-02-22 16:42:48,931 | DEBUG: http://metadata.google.internal:80 "GET /computeMetadata/v1/instance/service-accounts/806181930442-compute@developer.gserviceaccount.com/token?scopes=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_only%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_write HTTP/1.1" 200 260
# 2021-02-22 16:42:48,934 | DEBUG: Starting new HTTPS connection (1): storage.googleapis.com:443
# 2021-02-22 16:42:49,052 | DEBUG: https://storage.googleapis.com:443 "POST /upload/storage/v1/b/exoplanets_kubeflow/o?uploadType=resumable HTTP/1.1" 200 0
# 2021-02-22 16:42:49,585 | DEBUG: https://storage.googleapis.com:443 "PUT /upload/storage/v1/b/exoplanets_kubeflow/o?uploadType=resumable&upload_id=ABg5-Uy5dm4DFIgXwnShXwsbimEQLqJeDhj8pxExi1M5fMKwTCQaQ8Lfts9aMG5-M1g9ucEUnvaP_fGJhv21FmdH3O7fgo-CTQ HTTP/1.1" 200 853
# 2021-02-22 16:42:49,586 | INFO: Exoplanets Pipeline: Blob eval_dmatrix.data uploaded to preprocess/eval_dmatrix.data
# 2021-02-22 16:42:49,588 | DEBUG: Checking None for explicit credentials as part of auth process...
# 2021-02-22 16:42:49,589 | DEBUG: Checking Cloud SDK credentials as part of auth process...
# 2021-02-22 16:42:49,590 | DEBUG: Cloud SDK credentials not found on disk; not using them
# 2021-02-22 16:42:49,591 | DEBUG: Checking for App Engine runtime as part of auth process...
# 2021-02-22 16:42:49,591 | DEBUG: No App Engine library was found so cannot authentication via App Engine Identity Credentials.
# 2021-02-22 16:42:49,593 | DEBUG: Making request: GET http://169.254.169.254
# 2021-02-22 16:42:49,599 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/project/project-id
# 2021-02-22 16:42:49,603 | DEBUG: Checking None for explicit credentials as part of auth process...
# 2021-02-22 16:42:49,604 | DEBUG: Checking Cloud SDK credentials as part of auth process...
# 2021-02-22 16:42:49,605 | DEBUG: Cloud SDK credentials not found on disk; not using them
# 2021-02-22 16:42:49,606 | DEBUG: Checking for App Engine runtime as part of auth process...
# 2021-02-22 16:42:49,607 | DEBUG: No App Engine library was found so cannot authentication via App Engine Identity Credentials.
# 2021-02-22 16:42:49,609 | DEBUG: Making request: GET http://169.254.169.254
# 2021-02-22 16:42:49,612 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/project/project-id
# 2021-02-22 16:42:49,616 | DEBUG: Converted retries value: 3 -> Retry(total=3, connect=None, read=None, redirect=None, status=None)
# 2021-02-22 16:42:49,617 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true
# 2021-02-22 16:42:49,620 | DEBUG: Starting new HTTP connection (1): metadata.google.internal:80
# 2021-02-22 16:42:49,623 | DEBUG: http://metadata.google.internal:80 "GET /computeMetadata/v1/instance/service-accounts/default/?recursive=true HTTP/1.1" 200 193
# 2021-02-22 16:42:49,625 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/806181930442-compute@developer.gserviceaccount.com/token?scopes=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_only%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_write
# 2021-02-22 16:42:49,630 | DEBUG: http://metadata.google.internal:80 "GET /computeMetadata/v1/instance/service-accounts/806181930442-compute@developer.gserviceaccount.com/token?scopes=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_only%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_write HTTP/1.1" 200 260
# 2021-02-22 16:42:49,633 | DEBUG: Starting new HTTPS connection (1): storage.googleapis.com:443
# 2021-02-22 16:42:49,766 | DEBUG: https://storage.googleapis.com:443 "POST /upload/storage/v1/b/exoplanets_kubeflow/o?uploadType=resumable HTTP/1.1" 200 0
# 2021-02-22 16:42:50,155 | DEBUG: https://storage.googleapis.com:443 "PUT /upload/storage/v1/b/exoplanets_kubeflow/o?uploadType=resumable&upload_id=ABg5-UxwC1i2T-Ly2BBVktgLxoZtizkLKRsTOPkUu5uJiBm-W-e8eEjR8c_8lWAdk1FWN94wAhbYT3P-tCTVKIHA7V28tOVh_A HTTP/1.1" 200 853
# 2021-02-22 16:42:50,157 | INFO: Exoplanets Pipeline: Blob test_dmatrix.data uploaded to preprocess/test_dmatrix.data
# 2021-02-22 16:42:50,158 | INFO: Exoplanets Pipeline - Preprocess: Completed

# %%
'''
Wrapper around the xgboost train function.
This code perform:

- Load DMatrix from GCP bucket
- Run XGBoost model Training
- Save model inside the Bucket
'''
import argparse
import logging
import joblib
import xgboost as xgb
from google.cloud import storage

# logger configuration
logging.basicConfig(format='%(asctime)s | %(levelname)s: %(message)s', level=logging.NOTSET)

def _get_blob_bucket(bucket_name, path, destination):
    """Downloads a blob from the bucket."""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)

    blob = bucket.blob(path)
    blob.download_to_filename(destination)
    
    logging.info('Exoplanets Pipeline: Blob {} downloaded to {}'.format(path, 
                                                                        destination))
    return destination

def _upload_blob_bucket(bucket_name, source_file_name, destination):
    """Uploads a file to the bucket."""

    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    
    blob = bucket.blob(destination)
    blob.upload_from_filename(source_file_name)
    
    logging.info('Exoplanets Pipeline: Blob {} uploaded to {}'.format(source_file_name,
                                                                      destination))
def _xgb_parameters(scale_positive):
    
    parameters = {
    'eta': 0.05,
    'objective': 'binary:logistic',
    'max_depth': 7, # depth of the trees in the boosting process
    'min_child_weight': 1, 
    'colsample_bytree': 0.8,
    'scale_pos_weight' : scale_positive
    }
    
    return parameters

def trainer(bucket):
    
    logging.info('Exoplanets Pipeline - Trainer: Load DMatrices from {0} bucket'.format(bucket))
    # define input bucket-path of the data
    train_dmatrix_path = _get_blob_bucket(bucket, "preprocess/train_dmatrix.data", "train_dmatrix.data")
    eval_dmatrix_path = _get_blob_bucket(bucket, "preprocess/eval_dmatrix.data", "eval_dmatrix.data")
    
    dtrain = xgb.DMatrix(train_dmatrix_path)
    deval = xgb.DMatrix(eval_dmatrix_path)
    
    label, count = np.unique(dtrain.get_label(), return_counts=True)
    scale_positive = count[0] / count[1]
    watchlist = [(dtrain, 'train'), (deval, 'eval')]
    
    ESTIMATORS = 300
    model = xgb.train(_xgb_parameters(scale_positive), dtrain, ESTIMATORS, watchlist, early_stopping_rounds=10)
    
    logging.info('Exoplanets Pipeline - Trainer: Storing model on the bucket')
    joblib.dump(model, 'xgb_model.pkl') 
    _upload_blob_bucket(bucket, "xgb_model.pkl", "model/xgb_model.pkl")
    
    logging.info('Exoplanets Pipeline - Trainer: Job Completed')

# %%
bucket = "exoplanets_kubeflow"

# %%
logging.info('Exoplanets Pipeline - Trainer: Running...')
trainer(bucket)
# Out:
# 2021-02-22 16:46:52,290 | INFO: Exoplanets Pipeline - Train: Running...
# 2021-02-22 16:46:52,292 | INFO: Exoplanets Pipeline - Trainer: Load DMatrices from exoplanets_kubeflow bucket
# 2021-02-22 16:46:52,293 | DEBUG: Checking None for explicit credentials as part of auth process...
# 2021-02-22 16:46:52,295 | DEBUG: Checking Cloud SDK credentials as part of auth process...
# 2021-02-22 16:46:52,296 | DEBUG: Cloud SDK credentials not found on disk; not using them
# 2021-02-22 16:46:52,297 | DEBUG: Checking for App Engine runtime as part of auth process...
# 2021-02-22 16:46:52,298 | DEBUG: No App Engine library was found so cannot authentication via App Engine Identity Credentials.
# 2021-02-22 16:46:52,298 | DEBUG: Making request: GET http://169.254.169.254
# 2021-02-22 16:46:52,302 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/project/project-id
# 2021-02-22 16:46:52,306 | DEBUG: Checking None for explicit credentials as part of auth process...
# 2021-02-22 16:46:52,307 | DEBUG: Checking Cloud SDK credentials as part of auth process...
# 2021-02-22 16:46:52,308 | DEBUG: Cloud SDK credentials not found on disk; not using them
# 2021-02-22 16:46:52,309 | DEBUG: Checking for App Engine runtime as part of auth process...
# 2021-02-22 16:46:52,310 | DEBUG: No App Engine library was found so cannot authentication via App Engine Identity Credentials.
# 2021-02-22 16:46:52,310 | DEBUG: Making request: GET http://169.254.169.254
# 2021-02-22 16:46:52,315 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/project/project-id
# 2021-02-22 16:46:52,334 | DEBUG: Converted retries value: 3 -> Retry(total=3, connect=None, read=None, redirect=None, status=None)
# 2021-02-22 16:46:52,336 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true
# 2021-02-22 16:46:52,338 | DEBUG: Starting new HTTP connection (1): metadata.google.internal:80
# 2021-02-22 16:46:52,343 | DEBUG: http://metadata.google.internal:80 "GET /computeMetadata/v1/instance/service-accounts
| DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/806181930442-compute@developer.gserviceaccount.com/token?scopes=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_only%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_write
# 2021-02-22 16:48:16,437 | DEBUG: http://metadata.google.internal:80 "GET /computeMetadata/v1/instance/service-accounts/806181930442-compute@developer.gserviceaccount.com/token?scopes=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_only%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_write HTTP/1.1" 200 260
# 2021-02-22 16:48:16,441 | DEBUG: Starting new HTTPS connection (1): storage.googleapis.com:443
# 2021-02-22 16:48:16,723 | DEBUG: https://storage.googleapis.com:443 "POST /upload/storage/v1/b/exoplanets_kubeflow/o?uploadType=multipart HTTP/1.1" 200 815
# 2021-02-22 16:48:16,725 | INFO: Exoplanets Pipeline: Blob xgb_model.pkl uploaded to model/xgb_model.pkl
# 2021-02-22 16:48:16,726 | INFO: Exoplanets Pipeline - Train: Completed

# %%
'''
Wrapper around to perform prediction over a test dataset.
This code perform:

- Load model from GCP bucket
- Run prediction over test set
- Save confusion matrix inside the bucket
'''
import argparse
import logging
import numpy as np
import joblib
import xgboost as xgb
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from google.cloud import storage

# logger configuration
logging.basicConfig(format='%(asctime)s | %(levelname)s: %(message)s', level=logging.NOTSET)

def _get_blob_bucket(bucket_name, path, destination):
    """Downloads a blob from the bucket."""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)

    blob = bucket.blob(path)
    blob.download_to_filename(destination)
    
    logging.info('Exoplanets Pipeline: Blob {} downloaded to {}'.format(path, destination))
    return destination

def _upload_blob_bucket(bucket_name, source_file_name, destination):
    """Uploads a file to the bucket."""

    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    
    blob = bucket.blob(destination)
    blob.upload_from_filename(source_file_name)
    
    logging.info('Exoplanets Pipeline: Blob {} uploaded to {}'.format(source_file_name,
                                                                      destination))
    
def prediction(bucket):
    
    logging.info('Exoplanets Pipeline - Prediction: Load model from {0} bucket'.format(bucket))
    # define input bucket-path of the model
    model_path = _get_blob_bucket(bucket, "model/xgb_model.pkl", "xgb_model.pkl")
    test_dmatrix_path = _get_blob_bucket(bucket, "preprocess/test_dmatrix.data", "test_dmatrix.data")
    
    model = joblib.load(model_path)
    dtest = xgb.DMatrix(test_dmatrix_path)
    
    logging.info('Exoplanets Pipeline - Prediction: Perform Prediction')
    y_pred = model.predict(dtest)
    y_pred_binary = np.around(y_pred)
    
    logging.info('Exoplanets Pipeline - Prediction: Calculare metrics')
    cm = confusion_matrix(dtest.get_label(), y_pred_binary)
    precision = precision_score(dtest.get_label(), y_pred_binary)
    recall = recall_score(dtest.get_label(), y_pred_binary)
    
    logging.info('Exoplanets Pipeline - Prediction: Confusion matrix: \n {0}'.format(cm))
    logging.info('Exoplanets Pipeline - Prediction: Precision {0}'.format(precision))
    logging.info('Exoplanets Pipeline - Prediction: Recall {0}'.format(recall))
    
    logging.info('Exoplanets Pipeline - Prediction: Complete')

# %%
bucket = "exoplanets_kubeflow"

# %%
logging.info('Exoplanets Pipeline - Prediction: Running...')
prediction(bucket)
# Out:
# 2021-02-22 16:48:19,962 | INFO: Exoplanets Pipeline - Prediction: Running...
# 2021-02-22 16:48:19,963 | INFO: Exoplanets Pipeline - Prediction: Load model from exoplanets_kubeflow bucket
# 2021-02-22 16:48:19,965 | DEBUG: Checking None for explicit credentials as part of auth process...
# 2021-02-22 16:48:19,966 | DEBUG: Checking Cloud SDK credentials as part of auth process...
# 2021-02-22 16:48:19,966 | DEBUG: Cloud SDK credentials not found on disk; not using them
# 2021-02-22 16:48:19,968 | DEBUG: Checking for App Engine runtime as part of auth process...
# 2021-02-22 16:48:19,969 | DEBUG: No App Engine library was found so cannot authentication via App Engine Identity Credentials.
# 2021-02-22 16:48:19,970 | DEBUG: Making request: GET http://169.254.169.254
# 2021-02-22 16:48:19,974 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/project/project-id
# 2021-02-22 16:48:19,978 | DEBUG: Checking None for explicit credentials as part of auth process...
# 2021-02-22 16:48:19,979 | DEBUG: Checking Cloud SDK credentials as part of auth process...
# 2021-02-22 16:48:19,980 | DEBUG: Cloud SDK credentials not found on disk; not using them
# 2021-02-22 16:48:19,981 | DEBUG: Checking for App Engine runtime as part of auth process...
# 2021-02-22 16:48:19,982 | DEBUG: No App Engine library was found so cannot authentication via App Engine Identity Credentials.
# 2021-02-22 16:48:19,983 | DEBUG: Making request: GET http://169.254.169.254
# 2021-02-22 16:48:19,988 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/project/project-id
# 2021-02-22 16:48:19,991 | DEBUG: Converted retries value: 3 -> Retry(total=3, connect=None, read=None, redirect=None, status=None)
# 2021-02-22 16:48:19,993 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true
# 2021-02-22 16:48:19,995 | DEBUG: Starting new HTTP connection (1): metadata.google.internal:80
# 2021-02-22 16:48:20,000 | DEBUG: http://metadata.google.internal:80 "GET /computeMetadata/v1/instance/service-accounts/default/?recursive=true HTTP/1.1" 200 193
# 2021-02-22 16:48:20,002 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/806181930442-compute@developer.gserviceaccount.com/token?scopes=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_only%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_write
# 2021-02-22 16:48:20,007 | DEBUG: http://metadata.google.internal:80 "GET /computeMetadata/v1/instance/service-accounts/806181930442-compute@developer.gserviceaccount.com/token?scopes=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_only%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_write HTTP/1.1" 200 260
# 2021-02-22 16:48:20,011 | DEBUG: Starting new HTTPS connection (1): storage.googleapis.com:443
# 2021-02-22 16:48:20,107 | DEBUG: https://storage.googleapis.com:443 "GET /download/storage/v1/b/exoplanets_kubeflow/o/model%2Fxgb_model.pkl?alt=media HTTP/1.1" 200 322266
# 2021-02-22 16:48:20,117 | INFO: Exoplanets Pipeline: Blob model/xgb_model.pkl downloaded to xgb_model.pkl
# 2021-02-22 16:48:20,118 | DEBUG: Checking None for explicit credentials as part of auth process...
# 2021-02-22 16:48:20,119 | DEBUG: Checking Cloud SDK credentials as part of auth process...
# 2021-02-22 16:48:20,119 | DEBUG: Cloud SDK credentials not found on disk; not using them
# 2021-02-22 16:48:20,120 | DEBUG: Checking for App Engine runtime as part of auth process...
# 2021-02-22 16:48:20,121 | DEBUG: No App Engine library was found so cannot authentication via App Engine Identity Credentials.
# 2021-02-22 16:48:20,121 | DEBUG: Making request: GET http://169.254.169.254
# 2021-02-22 16:48:20,126 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/project/project-id
# 2021-02-22 16:48:20,130 | DEBUG: Checking None for explicit credentials as part of auth process...
# 2021-02-22 16:48:20,131 | DEBUG: Checking Cloud SDK credentials as part of auth process...
# 2021-02-22 16:48:20,132 | DEBUG: Cloud SDK credentials not found on disk; not using them
# 2021-02-22 16:48:20,132 | DEBUG: Checking for App Engine runtime as part of auth process...
# 2021-02-22 16:48:20,133 | DEBUG: No App Engine library was found so cannot authentication via App Engine Identity Credentials.
# 2021-02-22 16:48:20,134 | DEBUG: Making request: GET http://169.254.169.254
# 2021-02-22 16:48:20,138 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/project/project-id
# 2021-02-22 16:48:20,146 | DEBUG: Converted retries value: 3 -> Retry(total=3, connect=None, read=None, redirect=None, status=None)
# 2021-02-22 16:48:20,148 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true
# 2021-02-22 16:48:20,156 | DEBUG: Starting new HTTP connection (1): metadata.google.internal:80
# 2021-02-22 16:48:20,162 | DEBUG: http://metadata.google.internal:80 "GET /computeMetadata/v1/instance/service-accounts/default/?recursive=true HTTP/1.1" 200 193
# 2021-02-22 16:48:20,164 | DEBUG: Making request: GET http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/806181930442-compute@developer.gserviceaccount.com/token?scopes=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_only%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_write
# 2021-02-22 16:48:20,169 | DEBUG: http://metadata.google.internal:80 "GET /computeMetadata/v1/instance/service-accounts/806181930442-compute@developer.gserviceaccount.com/token?scopes=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_only%2Chttps%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.read_write HTTP/1.1" 200 260
# 2021-02-22 16:48:20,174 | DEBUG: Starting new HTTPS connection (1): storage.googleapis.com:443
# 2021-02-22 16:48:20,339 | DEBUG: https://storage.googleapis.com:443 "GET /download/storage/v1/b/exoplanets_kubeflow/o/preprocess%2Ftest_dmatrix.data?alt=media HTTP/1.1" 200 14585662
# 2021-02-22 16:48:20,479 | INFO: Exoplanets Pipeline: Blob preprocess/test_dmatrix.data downloaded to test_dmatrix.data
# 2021-02-22 16:48:20,511 | INFO: Exoplanets Pipeline - Prediction: Perform Prediction
# 2021-02-22 16:48:20,525 | INFO: Exoplanets Pipeline - Prediction: Calculare metrics
# 2021-02-22 16:48:20,531 | INFO: Exoplanets Pipeline - Prediction: Confusion matrix:
#  [[565   0]
#  [  4   1]]
# 2021-02-22 16:48:20,532 | INFO: Exoplanets Pipeline - Prediction: Precision 1.0
# 2021-02-22 16:48:20,533 | INFO: Exoplanets Pipeline - Prediction: Recall 0.2
# 2021-02-22 16:48:20,534 | INFO: Exoplanets Pipeline - Prediction: Complete
